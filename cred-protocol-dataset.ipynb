# %%
import pandas as pd
import numpy as np

# %%
chunksize = 1000
df = None
for chunk in pd.read_csv("aave-v2-health-factor-complete.csv",chunksize=chunksize):
    df = chunk
    break

# %%
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)

# %%
df1 = pd.read_csv("aave-v2-health-factor-complete.csv")

# %%
1649665816-1649040026, 1650291359- 1649665816
# Out:
# (625790, 625543)

# %%
df1[df1['address']=='0x0000ce08fa224696a819877070bf378e8b131acf'].sort_values('block_timestamp')
# Out:
#           block      block_timestamp  aave_Deposit_Count  aave_LiqThreshold  \
# 199  14515603.0  2022-04-03 21:40:26                 0.0                0.0
# 200  14561971.0  2022-04-11 03:30:16                 0.0                0.0
# 201  14608339.0  2022-04-18 09:15:59                 0.0                0.0
# 202  14654707.0  2022-04-25 15:56:30                 0.0                0.0
# 203  14701075.0  2022-05-02 23:01:53                 0.0                0.0
# 204  14747443.0  2022-05-10 08:04:34                 0.0                0.0
# 205  14793811.0  2022-05-17 17:19:00                 0.0                0.0
# 206  14840179.0  2022-05-25 05:54:47                 0.0                0.0
# 207  14886547.0  2022-06-01 19:16:03                 0.0                0.0
# 208  14932915.0  2022-06-09 13:47:34                 0.0                0.0
# 209  14979283.0  2022-06-17 12:59:11                 0.0                0.0
# ...

# %%
a = [print(col) for col in df1.columns]
# Out:
# block
# block_timestamp
# aave_Deposit_Count
# aave_LiqThreshold
# aaave_balance
# aave_Debt_Count
# variabledebtaave
# variabledebtaave_borrow
# stabledebtaave_borrow
# stabledebtaave
# aave_eth
# ampl_Deposit_Count
# ampl_LiqThreshold
# aampl_balance
# ampl_Debt_Count
# variabledebtampl
# variabledebtampl_borrow
# stabledebtampl_borrow
# stabledebtampl
# ampl_eth
# bal_Deposit_Count
# bal_LiqThreshold
# abal_balance
# bal_Debt_Count
# variabledebtbal
# variabledebtbal_borrow
# stabledebtbal_borrow
# stabledebtbal
# bal_eth
# bat_Deposit_Count
# bat_LiqThreshold
# abat_balance
# bat_Debt_Count
# variabledebtbat
# variabledebtbat_borrow
# stabledebtbat_borrow
# stabledebtbat
# bat_eth
# busd_Deposit_Count
# busd_LiqThreshold
# abusd_balance
# busd_Debt_Count
# variabledebtbusd
# variabledebtbusd_borrow
# stabledebtbusd_borrow
# stabledebtbusd
# busd_eth
# crv_Deposit_Count
# crv_LiqThreshold
# acrv_balance
# crv_Debt_Count
# variabledebtcrv
# variabledebtcrv_borrow
# ...

# %%
dfd = df1.describe()
# Out:
# c:\users\86651\miniconda3\lib\site-packages\numpy\lib\function_base.py:3961: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
dfd.iloc[:,0:15]
# Out:
#               block  aave_Deposit_Count  aave_LiqThreshold  aaave_balance  \
# count  1.333682e+06        1.333682e+06       1.333682e+06   1.333682e+06
# mean   1.375565e+07        9.159388e+01       2.802497e-02   9.159391e+01
# std    8.918876e+05        1.113194e+04       1.355188e-01   1.113194e+04
# min    1.145532e+07        0.000000e+00       0.000000e+00   0.000000e+00
# 25%    1.307820e+07        0.000000e+00       0.000000e+00   0.000000e+00
# 50%    1.386645e+07        0.000000e+00       0.000000e+00   0.000000e+00
# 75%    1.451560e+07        0.000000e+00       0.000000e+00   0.000000e+00
# max    1.502565e+07        2.227781e+06       7.000000e-01   2.227781e+06
#
#        aave_Debt_Count  variabledebtaave  variabledebtaave_borrow  \
# count        1333682.0         1333682.0                1333682.0
# mean               0.0               0.0                      0.0
# std                0.0               0.0                      0.0
# ...

# %%
df1[df1['aave_LiqThreshold']!=0]
# Out:
#               block      block_timestamp  aave_Deposit_Count  \
# 420      13031827.0  2021-08-15 20:06:10           10.972448
# 421      13078195.0  2021-08-22 23:44:25           10.972448
# 422      13124563.0  2021-08-30 03:57:27           41.369771
# 423      13170931.0  2021-09-06 07:48:43           41.369788
# 424      13217299.0  2021-09-13 12:16:01           56.562373
# ...             ...                  ...                 ...
# 1332952  14886547.0  2022-06-01 19:16:03           17.384367
# 1332953  14932915.0  2022-06-09 13:47:34           17.384367
# 1332954  14979283.0  2022-06-17 12:59:11           17.384362
# 1332955  15025651.0  2022-06-25 21:24:39           17.384367
# 1333682         NaN                  NaN                 NaN
#
#          aave_LiqThreshold  aaave_balance  aave_Debt_Count  variabledebtaave  \
# 420                   0.65      10.972448              0.0               0.0
# ...
