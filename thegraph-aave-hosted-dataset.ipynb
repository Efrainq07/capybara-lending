# %%
import pandas as pd
import numpy as np
import requests as req
import json

# %%
aave_url = "https://api.thegraph.com/subgraphs/name/aave/protocol-v2"

# %% [markdown]
# # User Transaction Data
# Obtain data for every transaction every user has done. Types of transactions are:
# - **deposit:** User deposits funds to use as collateral.
#
#
# - **redeem:** User redeems aTokens (obtained when depositing collateral) for their underlying asset. Effectively doing a withdraw from their collateral.
#
#
# - **borrow:** User borrows assets against the deposited collateral or against credit delegated by another user.
#
#
# - **repay:** User repays previous borrowing of an asseet
#
#
# - **swap:** User changes the borrow mode either from stable to variable or from variable to stable.
#
#
# - **rebalance:** Stable borrow rates are updated according to the new pool data.
#
#
# - **liquidation:** User's position is liquidated when their loan's health factor gets below the liquidation threshold, losing the deposited colateral.

# %%
users_query = """
query userBorrowHistory($lastUserId: String = "0x000000000000512644392395185ad535410f98c2") {
  users(first: 1000, orderBy: id, where:{
    id_gt:$lastUserId
  }) {
    id
    depositHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      amount
      reserve {
        ...ReserveFields
      }
    }
    redeemUnderlyingHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      amount
      reserve {
        ...ReserveFields
      }
    }
    borrowHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      amount
      stableTokenDebt
      variableTokenDebt
      borrowRateMode
      borrowRate
      reserve {
        ...ReserveFields
      }
    }
    repayHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      amount
      reserve {
        ...ReserveFields
      }
    }
    swapHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      borrowRateModeFrom
      borrowRateModeTo
      stableBorrowRate
      variableBorrowRate
      reserve{
        ...ReserveFields
      }
    }
    rebalanceStableBorrowRateHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      borrowRateFrom
      borrowRateTo
      reserve{
        ...ReserveFields
      }
    }
    liquidationCallHistory(first: 1000, orderBy: timestamp){
      ...TransactionFields
      collateralAmount
      principalAmount
      collateralReserve {
        ...ReserveFields
      }
      principalReserve {
        ...ReserveFields
      }
    }
  }
}

fragment TransactionFields on UserTransaction{
  id
  timestamp
}

fragment ReserveFields on Reserve{
  id
  symbol
  decimals
}
"""

# %%
users_payload = {
    'query' : users_query,
    'variables': {
        'lastUserId': "0x0000000000000000000000000000000000000001"
    }
}

# %%
userData = []

remainingUsers = []

while True:
    request = req.post(aave_url, json = users_payload)
    result = json.loads(request.content)
    filtered_result =[user for user in result['data']['users'] if not (
            len(user['depositHistory']) == 1000 or
            len(user['redeemUnderlyingHistory']) == 1000 or
            len(user['borrowHistory']) == 1000 or
            len(user['repayHistory']) == 1000 or
            len(user['rebalanceStableBorrowRateHistory']) == 1000 or
            len(user['swapHistory']) == 1000)]
            
        
    userData.extend(filtered_result)
    users_payload['variables']['lastUserId'] = userData[-1]['id']
    print(len(userData),userData[-1]['id'])
    if len(result['data']['users']) < 1000:
        break
# Out:
# 87988 0xe9e8e302527cbbf82d8f0db559c251e1bb016853
# 88987 0xeca817610c3b207200c1a2e0fee7e89f2710a88e
# 89987 0xef5c32bc7d3b153ef5892e95bb7b3b20aa293573
# 90987 0xf211d1166b9a07109174372fa2471e211ce7286f
# 91987 0xf4a22faec59f3b16328a9ecc9985edc92121c30c
# 92987 0xf71525327bcddc33a2e90e2665288b6075569367
# 93987 0xf9a2fa22cb7df26e3a10622c696f37fc345c6239
# 94987 0xfc1ac2b5288c3d4037a6e530ec4837921c79a189
# 95986 0xfed82a0f90d551a8058d5194e8df924d42e41557
# 96436 0xffffd1eb5a15ceb74d81f5c6097353a1056039c7

# %%
with open('aave_user_transaction_data_complete.json', 'w') as datafile:
    json.dump(userData, datafile)

# %% [markdown]
# # Reserve Data
# Obtain data for every asset reserve, specifically historical data about the Loan-To-Value ratio and liquidation threshold.

# %%
reserve_query = """
query ReserveHistory{
  reserves(first: 60){
    id
    symbol
    decimals
    lastUpdateTimestamp
    baseLTVasCollateral
    reserveLiquidationThreshold
    configurationHistory(orderBy:timestamp){
      id
      timestamp
      baseLTVasCollateral
      reserveLiquidationThreshold
    }
  }
}
"""

# %%
reserve_payload = {
    'query' : reserve_query,
}

# %%
request = req.post(aave_url, json = reserve_payload)
result = json.loads(request.content)

# %%
reserve_data = result['data']['reserves']

# %%
for reserve in result['data']['reserves']:
    reserve['configurationHistory'].append(
        {
            'id':'actual',
            'timestamp':  2**32,
            'baseLTVasCollateral': reserve['baseLTVasCollateral'],
            'reserveLiquidationThreshold': reserve['reserveLiquidationThreshold']
        }
    )

# %%
with open('aave_reserve_configuration_data_complete.json', 'w') as datafile:
    json.dump(reserve_data, datafile)

# %%
simple_reserve_query = """
query Reserves{
  reserves(first: 60){
    id
    underlyingAsset
    symbol
    decimals
    lastUpdateTimestamp
    baseLTVasCollateral
    reserveLiquidationThreshold
  }
}
"""

# %%
simple_reserve_payload = {
    'query' : simple_reserve_query,
}

# %%
request = req.post(aave_url, json = simple_reserve_payload)
result = json.loads(request.content)

# %%
reserve_data = result['data']['reserves']

# %%
reserve_data
# Out:
# [{'id': '0x0000000000085d4780b73119b644ae5ecd22b3760xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x0000000000085d4780b73119b644ae5ecd22b376',
#   'symbol': 'TUSD',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663308059,
#   'baseLTVasCollateral': '8000',
#   'reserveLiquidationThreshold': '8250'},
#  {'id': '0x004375dff511095cc5a197a54140a24efef3a4160xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x004375dff511095cc5a197a54140a24efef3a416',
#   'symbol': 'AmmUniWBTCUSDC',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1651982413,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x03ab458634910aad20ef5f1c8ee96f1d6ac549190xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x03ab458634910aad20ef5f1c8ee96f1d6ac54919',
#   'symbol': 'RAI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663287251,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x056fd409e1d7a124bd7017459dfea2f387b6d5cd0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x056fd409e1d7a124bd7017459dfea2f387b6d5cd',
#   'symbol': 'GUSD',
#   'decimals': 2,
#   'lastUpdateTimestamp': 1663310591,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e',
#   'symbol': 'YFI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663305527,
#   'baseLTVasCollateral': '5000',
#   'reserveLiquidationThreshold': '6500'},
#  {'id': '0x0d8775f648430679a709e98d2b0cb6250d2887ef0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x0d8775f648430679a709e98d2b0cb6250d2887ef',
#   'symbol': 'BAT',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663310927,
#   'baseLTVasCollateral': '7500',
#   'reserveLiquidationThreshold': '8000'},
#  {'id': '0x0f5d2fb29fb7d3cfee444a200298f468908cc9420xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942',
#   'symbol': 'MANA',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663298399,
#   'baseLTVasCollateral': '6150',
#   'reserveLiquidationThreshold': '7500'},
#  {'id': '0x111111111117dc0aa78b770fa6a738034120c3020xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x111111111117dc0aa78b770fa6a738034120c302',
#   'symbol': '1INCH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663313435,
#   'baseLTVasCollateral': '4000',
#   'reserveLiquidationThreshold': '5000'},
#  {'id': '0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b',
#   'symbol': 'DPI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663283915,
#   'baseLTVasCollateral': '6500',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x1eff8af5d577060ba4ac8a29a13525bb0ee2a3d50xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x1eff8af5d577060ba4ac8a29a13525bb0ee2a3d5',
#   'symbol': 'AmmBptWBTCWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1658302300,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f9840xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#   'symbol': 'UNI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663317527,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7500'},
#  {'id': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c5990xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'symbol': 'AmmWBTC',
#   'decimals': 8,
#   'lastUpdateTimestamp': 1663201235,
#   'baseLTVasCollateral': '7000',
#   'reserveLiquidationThreshold': '7500'},
#  {'id': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c5990xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'symbol': 'WBTC',
#   'decimals': 8,
#   'lastUpdateTimestamp': 1663318991,
#   'baseLTVasCollateral': '7000',
#   'reserveLiquidationThreshold': '8000'},
#  {'id': '0x2fdbadf3c4d5a8666bc06645b8358ab803996e280xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x2fdbadf3c4d5a8666bc06645b8358ab803996e28',
#   'symbol': 'AmmUniYFIWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1662744684,
#   'baseLTVasCollateral': '5000',
#   'reserveLiquidationThreshold': '6000'},
#  {'id': '0x3da1313ae46132a397d90d95b1424a9a7e3e0fce0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x3da1313ae46132a397d90d95b1424a9a7e3e0fce',
#   'symbol': 'AmmUniCRVWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1649578446,
#   'baseLTVasCollateral': '5000',
#   'reserveLiquidationThreshold': '6000'},
#  {'id': '0x408e41876cccdc0f92210600ef50372656052a380xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x408e41876cccdc0f92210600ef50372656052a38',
#   'symbol': 'REN',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663310483,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '6500'},
#  {'id': '0x43ae24960e5534731fc831386c07755a2dc33d470xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x43ae24960e5534731fc831386c07755a2dc33d47',
#   'symbol': 'AmmUniSNXWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1635809372,
#   'baseLTVasCollateral': '4000',
#   'reserveLiquidationThreshold': '6000'},
#  {'id': '0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b',
#   'symbol': 'CVX',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663299779,
#   'baseLTVasCollateral': '4500',
#   'reserveLiquidationThreshold': '6000'},
#  {'id': '0x4fabb145d64652a948d72533023f6e7a623c7c530xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x4fabb145d64652a948d72533023f6e7a623c7c53',
#   'symbol': 'BUSD',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663314755,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x50379f632ca68d36e50cfbc8f78fe16bd1499d1e0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x50379f632ca68d36e50cfbc8f78fe16bd1499d1e',
#   'symbol': 'AmmGUniDAIUSDC',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1642769532,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x514910771af9ca656af840dff83e8264ecf986ca0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x514910771af9ca656af840dff83e8264ecf986ca',
#   'symbol': 'LINK',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663313807,
#   'baseLTVasCollateral': '7000',
#   'reserveLiquidationThreshold': '8300'},
#  {'id': '0x57ab1ec28d129707052df4df418d58a2d46d5f510xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x57ab1ec28d129707052df4df418d58a2d46d5f51',
#   'symbol': 'SUSD',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663314287,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x59a19d8c652fa0284f44113d0ff9aba70bd46fb40xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x59a19d8c652fa0284f44113d0ff9aba70bd46fb4',
#   'symbol': 'AmmBptBALWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1662016275,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x5f98805a4e8be255a32880fdec7f6728c6568ba00xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x5f98805a4e8be255a32880fdec7f6728c6568ba0',
#   'symbol': 'LUSD',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663240523,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x6b175474e89094c44da98b954eedeac495271d0f0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x6b175474e89094c44da98b954eedeac495271d0f',
#   'symbol': 'AmmDAI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663296467,
#   'baseLTVasCollateral': '7500',
#   'reserveLiquidationThreshold': '8000'},
#  {'id': '0x6b175474e89094c44da98b954eedeac495271d0f0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x6b175474e89094c44da98b954eedeac495271d0f',
#   'symbol': 'DAI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663315619,
#   'baseLTVasCollateral': '7700',
#   'reserveLiquidationThreshold': '9000'},
#  {'id': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae90xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9',
#   'symbol': 'AAVE',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663289447,
#   'baseLTVasCollateral': '6250',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x853d955acef822db058eb8505911ed77f175b99e0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x853d955acef822db058eb8505911ed77f175b99e',
#   'symbol': 'FRAX',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663317503,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x8798249c2e607446efb7ad49ec89dd1865ff42720xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x8798249c2e607446efb7ad49ec89dd1865ff4272',
#   'symbol': 'XSUSHI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663310123,
#   'baseLTVasCollateral': '5000',
#   'reserveLiquidationThreshold': '6500'},
#  {'id': '0x8bd1661da98ebdd3bd080f0be4e6d9be8ce9858c0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0x8bd1661da98ebdd3bd080f0be4e6d9be8ce9858c',
#   'symbol': 'AmmUniRENWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1635809372,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0x8e870d67f660d95d5be530380d0ec0bd388289e10xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x8e870d67f660d95d5be530380d0ec0bd388289e1',
#   'symbol': 'PAX',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663065137,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0x956f47f50a910163d8bf957cf5846d573e7f87ca0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x956f47f50a910163d8bf957cf5846d573e7f87ca',
#   'symbol': 'FEI',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663266755,
#   'baseLTVasCollateral': '6500',
#   'reserveLiquidationThreshold': '7500'},
#  {'id': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a20xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2',
#   'symbol': 'MKR',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663313567,
#   'baseLTVasCollateral': '6500',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb480xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'symbol': 'AmmUSDC',
#   'decimals': 6,
#   'lastUpdateTimestamp': 1663315151,
#   'baseLTVasCollateral': '8000',
#   'reserveLiquidationThreshold': '8500'},
#  {'id': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb480xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'symbol': 'USDC',
#   'decimals': 6,
#   'lastUpdateTimestamp': 1663318739,
#   'baseLTVasCollateral': '8550',
#   'reserveLiquidationThreshold': '8800'},
#  {'id': '0xa2107fa5b38d9bbd2c461d6edf11b11a50f6b9740xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xa2107fa5b38d9bbd2c461d6edf11b11a50f6b974',
#   'symbol': 'AmmUniLINKWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1660828283,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb110xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11',
#   'symbol': 'AmmUniDAIWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1652554722,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xa693b19d2931d498c5b318df961919bb4aee87a50xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xa693b19d2931d498c5b318df961919bb4aee87a5',
#   'symbol': 'UST',
#   'decimals': 6,
#   'lastUpdateTimestamp': 1663037548,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d50xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5',
#   'symbol': 'AmmUniDAIUSDC',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1635809372,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xae7ab96520de3a18e5e111b5eaab095312d7fe840xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xae7ab96520de3a18e5e111b5eaab095312d7fe84',
#   'symbol': 'STETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663318883,
#   'baseLTVasCollateral': '6900',
#   'reserveLiquidationThreshold': '8100'},
#  {'id': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc',
#   'symbol': 'AmmUniUSDCWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1659973071,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xb6909b960dbbe7392d405429eb2b3649752b48380xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xb6909b960dbbe7392d405429eb2b3649752b4838',
#   'symbol': 'AmmUniBATWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1646894739,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xba100000625a3754423978a60c9317c58a424e3d0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xba100000625a3754423978a60c9317c58a424e3d',
#   'symbol': 'BAL',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663310507,
#   'baseLTVasCollateral': '6500',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xbb2b8038a1640196fbe3e38816f3e67cba72d9400xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xbb2b8038a1640196fbe3e38816f3e67cba72d940',
#   'symbol': 'AmmUniWBTCWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1660307199,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f',
#   'symbol': 'SNX',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663306343,
#   'baseLTVasCollateral': '4900',
#   'reserveLiquidationThreshold': '6500'},
#  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc20xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'symbol': 'AmmWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663315115,
#   'baseLTVasCollateral': '8000',
#   'reserveLiquidationThreshold': '8250'},
#  {'id': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc20xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'symbol': 'WETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663318883,
#   'baseLTVasCollateral': '8250',
#   'reserveLiquidationThreshold': '8500'},
#  {'id': '0xc18360217d8f7ab5e7c516566761ea12ce7f9d720xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xc18360217d8f7ab5e7c516566761ea12ce7f9d72',
#   'symbol': 'ENS',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663278719,
#   'baseLTVasCollateral': '5000',
#   'reserveLiquidationThreshold': '6000'},
#  {'id': '0xc2adda861f89bbb333c90c492cb837741916a2250xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xc2adda861f89bbb333c90c492cb837741916a225',
#   'symbol': 'AmmUniMKRWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1652343461,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xd2eec91055f07fe24c9ccb25828ecfefd4be0c410xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xd2eec91055f07fe24c9ccb25828ecfefd4be0c41',
#   'symbol': 'AmmGUniUSDCUSDT',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1661952305,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xd3d2e2692501a5c9ca623199d38826e513033a170xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xd3d2e2692501a5c9ca623199d38826e513033a17',
#   'symbol': 'AmmUniUNIWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1662744815,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xd46ba6d942050d489dbd938a2c909a5d5039a1610xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xd46ba6d942050d489dbd938a2c909a5d5039a161',
#   'symbol': 'AMPL',
#   'decimals': 9,
#   'lastUpdateTimestamp': 1663308947,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0xd5147bc8e386d91cc5dbe72099dac6c9b99276f50xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xd5147bc8e386d91cc5dbe72099dac6c9b99276f5',
#   'symbol': 'RENFIL',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663157509,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0xd533a949740bb3306d119cc777fa900ba034cd520xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#   'symbol': 'CRV',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663313267,
#   'baseLTVasCollateral': '5500',
#   'reserveLiquidationThreshold': '6100'},
#  {'id': '0xdac17f958d2ee523a2206206994597c13d831ec70xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#   'symbol': 'AmmUSDT',
#   'decimals': 6,
#   'lastUpdateTimestamp': 1663205710,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0xdac17f958d2ee523a2206206994597c13d831ec70xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#   'symbol': 'USDT',
#   'decimals': 6,
#   'lastUpdateTimestamp': 1663318655,
#   'baseLTVasCollateral': '0',
#   'reserveLiquidationThreshold': '0'},
#  {'id': '0xdd974d5c2e2928dea5f71b9825b8b646686bd2000xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xdd974d5c2e2928dea5f71b9825b8b646686bd200',
#   'symbol': 'KNC',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663273895,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xdfc14d2af169b0d36c4eff567ada9b2e0cae044f0xacc030ef66f9dfeae9cbb0cd1b25654b82cfa8d5',
#   'underlyingAsset': '0xdfc14d2af169b0d36c4eff567ada9b2e0cae044f',
#   'symbol': 'AmmUniAAVEWETH',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1662771518,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '7000'},
#  {'id': '0xe41d2489571d322189246dafa5ebde1f4699f4980xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xe41d2489571d322189246dafa5ebde1f4699f498',
#   'symbol': 'ZRX',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663303487,
#   'baseLTVasCollateral': '6500',
#   'reserveLiquidationThreshold': '7500'},
#  {'id': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#   'underlyingAsset': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c',
#   'symbol': 'ENJ',
#   'decimals': 18,
#   'lastUpdateTimestamp': 1663289495,
#   'baseLTVasCollateral': '6000',
#   'reserveLiquidationThreshold': '6700'}]

# %%
with open('aave_reserve_data_simple.json', 'w') as datafile:
    json.dump(reserve_data, datafile)
